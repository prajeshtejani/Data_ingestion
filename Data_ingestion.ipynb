# %% [markdown]
# Create a utility file

# %%
# %%writefile testutility.py
import os
import yaml
import re
import logging

def read_config_file(filepath):
    with open(filepath, 'r') as stream:
        try:
            return yaml.safe_load(stream)
        except yaml.YAMLError as exc:
            logging.error(exc)

def remove_special_character(data,config_data):
      data.columns = data.columns.str.lower()
      data.columns = data.columns.str.replace('[^\w]','_',regex=True)
      data.columns = list(map(lambda x: x.strip('_'), list(data.columns)))
      expected_col = list(map(lambda x: x.lower(),  config_data['columns']))
      if len(data.columns) == len(expected_col) and list(expected_col)  == list(data.columns):
        print("column name and column length validation passed")
        return 1
      else:
        print("column name and column length validation failed")
        mismatched_columns_file = list(set(data.columns).difference(expected_col))
        print("Following File columns are not in the YAML file",mismatched_columns_file)
        missing_YAML_file = list(set(expected_col).difference(data.columns))
        print("Following YAML columns are not in the file uploaded",missing_YAML_file)
        logging.info(f'data columns: {data.columns}')
        logging.info(f'expected columns: {expected_col}')
        return 0
# Out:
# Overwriting testutility.py

# %% [markdown]
# 1st) "With the 1st function **read_config_fil**e we can read our YAML File as well as we can use this function to Open files".
# 2nd) "Function **remove_special_character** used to remove White space from column name and used for validation of number of column and column_name"..

# %%
# %%writefile file.yaml
# file_type: csv
# dataset_name: testfile
# file_name: yellow_tripdata_2015-01
# table_name: edsurv
# inbound_delimiter: ","
# outbound_delimiter: "|"
# skip_leading_rows: 1
# columns:
#     - VendorID
#     - passenger_count
#     - trip_distance
#     - payment_type
#     - fare_amount
#     - extra
#     - mta_tax
#     - tip_amount
#     - tolls_amount
#     - improvement_surcharge
#     - total_amount
# Out:
# Overwriting file.yaml

# %%
import testutility as util
config_data = util.read_config_file('file.yaml')

# %% [markdown]
# Reading_file with pandas

# %%
import pandas as pd
data = pd.read_csv('yellow_tripdata_2015-01.csv',on_bad_lines='skip')
data_top = data.head()

# %%
data_top
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2015-01-15 19:05:39   2015-01-15 19:23:42              1.0
# 1         1  2015-01-10 20:33:38   2015-01-10 20:53:28              1.0
# 2         1  2015-01-10 20:33:38   2015-01-10 20:43:41              1.0
# 3         1  2015-01-10 20:33:39   2015-01-10 20:35:31              1.0
# 4         1  2015-01-10 20:33:39   2015-01-10 20:52:58              1.0
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           1.59        -73.993896        40.750111         1.0
# 1           3.30        -74.001648        40.724243         1.0
# 2           1.80        -73.963341        40.802788         1.0
# 3           0.50        -74.009087        40.713818         1.0
# 4           3.00        -73.971176        40.762428         1.0
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %% [markdown]
# Reading file with YAML file

# %%
filetype = config_data['file_type']
source_file = ""+ config_data['file_name']+f'.{filetype}'
data = pd.read_csv(source_file,config_data['inbound_delimiter'],on_bad_lines='skip')
data.head()
# Out:
# ...
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2015-01-15 19:05:39   2015-01-15 19:23:42                1
# 1         1  2015-01-10 20:33:38   2015-01-10 20:53:28                1
# 2         1  2015-01-10 20:33:38   2015-01-10 20:43:41                1
# 3         1  2015-01-10 20:33:39   2015-01-10 20:35:31                1
# 4         1  2015-01-10 20:33:39   2015-01-10 20:52:58                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           1.59        -73.993896        40.750111           1
# 1           3.30        -74.001648        40.724243           1
# 2           1.80        -73.963341        40.802788           1
# 3           0.50        -74.009087        40.713818           1
# 4           3.00        -73.971176        40.762428           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %%
# !python -m pip install "dask[complete]"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# Reading file with Dask

# %%
from numpy import dtype
import dask.dataframe as dd
df = dd.read_csv('yellow_tripdata_2015-01.csv',on_bad_lines='skip',dtype={'RateCodeID': 'float64',
       'payment_type': 'float64'})

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2015-01-15 19:05:39   2015-01-15 19:23:42                1
# 1         1  2015-01-10 20:33:38   2015-01-10 20:53:28                1
# 2         1  2015-01-10 20:33:38   2015-01-10 20:43:41                1
# 3         1  2015-01-10 20:33:39   2015-01-10 20:35:31                1
# 4         1  2015-01-10 20:33:39   2015-01-10 20:52:58                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           1.59        -73.993896        40.750111         1.0
# 1           3.30        -74.001648        40.724243         1.0
# 2           1.80        -73.963341        40.802788         1.0
# 3           0.50        -74.009087        40.713818         1.0
# 4           3.00        -73.971176        40.762428         1.0
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %% [markdown]
# from the execution time we can say Dask is more efficient then Pandas

# %% [markdown]
# Reading file with Modin

# %%
pip install "modin[ray]"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import ray
import modin.pandas as mpd
data = mpd.read_csv('yellow_tripdata_2015-01.csv',on_bad_lines='skip')

# %%
data.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2015-01-15 19:05:39   2015-01-15 19:23:42                1
# 1         1  2015-01-10 20:33:38   2015-01-10 20:53:28                1
# 2         1  2015-01-10 20:33:38   2015-01-10 20:43:41                1
# 3         1  2015-01-10 20:33:39   2015-01-10 20:35:31                1
# 4         1  2015-01-10 20:33:39   2015-01-10 20:52:58                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           1.59        -73.993896        40.750111           1
# 1           3.30        -74.001648        40.724243           1
# 2           1.80        -73.963341        40.802788           1
# 3           0.50        -74.009087        40.713818           1
# 4           3.00        -73.971176        40.762428           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %% [markdown]
# Modin[ray] takes more time than pandas and Dask

# %%
 if util.remove_special_character(data,config_data) == 0:
   print('Validation Failed')
 else:
    print('Validation passed')
# Out:
# column name and column length validation failed
# Following File columns are not in the YAML file ['pickup_latitude', 'ratecodeid', 'tpep_dropoff_datetime', 'tpep_pickup_datetime', 'pickup_longitude', 'dropoff_latitude', 'dropoff_longitude', 'store_and_fwd_flag']
# Following YAML columns are not in the file uploaded []
# Validation Failed

# %%
df = pd.read_csv(r'yellow_tripdata_2015-01.csv',on_bad_lines='skip') #read inputfile in a dataframe
df.to_csv(r'yellow_tripdata_2015-01_1.txt.gz', sep = '|', index=False) #write dataframe df to the outputfile with pipe delimited
